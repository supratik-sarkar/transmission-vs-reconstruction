# %% [markdown]
# # Transmission vs Reconstruction — Colab A100 template
# Use this notebook only after the experimental protocol is frozen. API keys belong in **Colab Secrets**, never in notebook cells.

# %%
import platform
import sys

print(sys.version)
print(platform.platform())
try:
    import torch

    print(
        "CUDA:",
        torch.cuda.is_available(),
        torch.cuda.get_device_name(0) if torch.cuda.is_available() else None,
    )
except Exception as e:
    print("torch unavailable:", e)

# %% [markdown]
# ## Mount Drive (optional private runtime storage)
# For public/API experiments you can also use ephemeral `/content/handoff-fidelity`; do not push private outputs to GitHub.

# %%
import os

from google.colab import drive

drive.mount("/content/drive")
os.environ["HANDOFF_PRIVATE_HOME"] = "/content/drive/MyDrive/handoff-fidelity"

# %% [markdown]
# ## Clone and install the public repo

# %%
REPO_URL = "https://github.com/supratik-sarkar/transmission-vs-reconstruction.git"
# !git clone {REPO_URL} /content/transmission-vs-reconstruction
# %cd /content/transmission-vs-reconstruction
# !pip install -e '.[dev,hf]'
# !handoff self-test

# %% [markdown]
# ## Secrets
# Retrieve provider credentials from Colab Secrets only when a frozen run actually needs them. Do **not** print them. Example:

# %%
# Uncomment only for a frozen API run.
# from google.colab import userdata
# os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')
# os.environ['ANTHROPIC_API_KEY'] = userdata.get('ANTHROPIC_API_KEY')
# os.environ['GEMINI_API_KEY'] = userdata.get('GEMINI_API_KEY')

# %% [markdown]
# ## Protocol check before any real run
# A real Stage-1 command must fail unless the private freeze record verifies.

# %%
# !handoff doctor
# !handoff stage1 --dry-run
